# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.49 🚀 Python-3.11.7 torch-2.2.2 CPU (Apple M1)
# Setup complete ✅ (8 CPUs, 16.0 GB RAM, 376.9/460.4 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /kaggle/working

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Hb453O1GT7isbtsP6O4w")
project = rf.workspace("hariyo-chasma").project("face-tracking-k58md")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 3.3 MB/s eta 0:00:00
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to face-tracking-1 in yolov11:: 100%|██████████| 2214/2214 [00:00<00:00, 8363.65it/s]

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8n.pt conf=0.25 data={dataset.location}/data.yaml epochs=100 imgsz=800
# Out:
# /kaggle/working
# ...
# 100%|███████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 106MB/s]
# New https://pypi.org/project/ultralytics/8.3.49 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...
